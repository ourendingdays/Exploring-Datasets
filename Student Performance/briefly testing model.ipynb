# %% [markdown]
# ### In this notebook I want to test which features are best to determine final grades, how they influence final grades; test scalers and model. This is like a playground.
#
# ### For more work with Feature Engineering and so on, refer to *student.ipynb*

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler

# %%
STUDENTS = pd.read_csv("student/student-por.csv", sep=';') 

STUDENTS.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df = STUDENTS

# %%
df.shape #Check the shape of the dataframe
# Out:
# (649, 33)

# %%
df["G"] = (df["G1"] + df["G2"] + df["G3"])/3

#Attributes to test
df=df[['studytime', 'failures', 'Dalc', 'Walc', 'traveltime', 'freetime', 'Medu', 'Fedu','G']]

# %%
df
# Out:
#      studytime  failures  Dalc  Walc  traveltime  freetime  Medu  Fedu  \
# 0            2         0     1     1           2         3     4     4
# 1            2         0     1     1           1         3     1     1
# 2            2         0     2     3           1         3     1     1
# 3            3         0     1     1           1         2     4     2
# 4            2         0     1     2           1         3     3     3
# ..         ...       ...   ...   ...         ...       ...   ...   ...
# 644          3         1     1     2           1         4     2     3
# 645          2         0     1     1           1         3     3     1
# 646          2         0     1     1           2         1     1     1
# 647          1         0     3     4           2         4     3     1
# 648          1         0     3     4           3         4     3     2
#
#              G
# 0     7.333333
# 1    10.333333
# 2    12.333333
# 3    14.000000
# 4    12.333333
# ..         ...
# ...

# %%
x=np.array(df.drop(['G'],1))
y=np.array(df['G'])

# %%
x
# Out:
# array([[2, 0, 1, ..., 3, 4, 4],
#        [2, 0, 1, ..., 3, 1, 1],
#        [2, 0, 2, ..., 3, 1, 1],
#        ...,
#        [2, 0, 1, ..., 1, 1, 1],
#        [1, 0, 3, ..., 4, 3, 1],
#        [1, 0, 3, ..., 4, 3, 2]])

# %%
y.shape
# Out:
# (649,)

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.33)

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(penalty="l2") # specifying Ridge Regression

sgd_reg.fit(x_train, y_train)

accuracy=sgd_reg.score(x_test,y_test)  
print(accuracy)
# Out:
# 0.3457805366935728

# %% [markdown]
# ----

# %%
STUDENTS
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
student = STUDENTS.copy()
student.drop('G', axis=1, inplace=True)
student.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
#Attributes to test
student = student[['studytime', 'failures', 'Dalc', 'Walc', 'traveltime', 'freetime', 'Medu', 'Fedu', 
                   'G1','G2','G3']]

# %%
student
# Out:
#      studytime  failures  Dalc  Walc  traveltime  freetime  Medu  Fedu  G1  \
# 0            2         0     1     1           2         3     4     4   0
# 1            2         0     1     1           1         3     1     1   9
# 2            2         0     2     3           1         3     1     1  12
# 3            3         0     1     1           1         2     4     2  14
# 4            2         0     1     2           1         3     3     3  11
# ..         ...       ...   ...   ...         ...       ...   ...   ...  ..
# 644          3         1     1     2           1         4     2     3  10
# 645          2         0     1     1           1         3     3     1  15
# 646          2         0     1     1           2         1     1     1  11
# 647          1         0     3     4           2         4     3     1  10
# 648          1         0     3     4           3         4     3     2  10
#
#      G2  G3
# 0    11  11
# 1    11  11
# 2    13  12
# 3    14  14
# ...

# %%
x = np.array(student.drop(['G3'],1))
y = np.array(student['G3'])

# %%
scaler_student = StandardScaler()

x = scaler_student.fit_transform(x)

# %%
x
# Out:
# array([[ 0.08365295, -0.37430512, -0.54355533, ...,  1.54071544,
#         -4.15547029, -0.19581961],
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -1.18883229,
#         -0.87456978, -0.19581961],
#        [ 0.08365295, -0.37430512,  0.53855329, ..., -1.18883229,
#          0.21906372,  0.49113675],
#        ...,
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -1.18883229,
#         -0.14548078,  0.14765857],
#        [-1.12280848, -0.37430512,  1.62066191, ..., -1.18883229,
#         -0.51002528, -0.53929779],
#        [-1.12280848, -0.37430512,  1.62066191, ..., -0.27898305,
#         -0.51002528, -0.19581961]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.33) 

sgd_reg_st = SGDRegressor(penalty="l2") # specifying Ridge Regression

sgd_reg_st.fit(x_train, y_train)

accuracy=sgd_reg_st.score(x_test,y_test)  
print(accuracy)
# Out:
# 0.8906044053536556

# %% [markdown]
# ### So, the predictions with *G1* and *G2* are incredibly great
#
# ## From what I can see, scale or not, the most influence on final grade have *G1* and *G2*. That was obvious. But that doesn't really stick with the logic of the task. Work during semester has the most impact on the grades, so why it doesn't work with plain *G*? *G* is the mean of these three grades and it must be somehow affected by other relevant aspects of student's life.

# %%
STUDENTS
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ### Let's see how it will work with Support Vector Machines

# %%
student_svm = STUDENTS.copy()

student_svm.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3          G
# 0        3     4     1     1       3        4   0  11  11   7.333333
# 1        3     3     1     1       3        2   9  11  11  10.333333
# 2        3     2     2     3       3        6  12  13  12  12.333333
# 3        2     2     1     1       5        0  14  14  14  14.000000
# 4        3     2     1     2       5        0  11  13  13  12.333333
#
# [5 rows x 34 columns]

# %%
#Attributes to test
student_svm = student_svm[['studytime', 'failures', 'Dalc', 'Walc', 'traveltime', 'freetime', 'Medu', 'Fedu','G']]   
student_svm
# Out:
#      studytime  failures  Dalc  Walc  traveltime  freetime  Medu  Fedu  \
# 0            2         0     1     1           2         3     4     4
# 1            2         0     1     1           1         3     1     1
# 2            2         0     2     3           1         3     1     1
# 3            3         0     1     1           1         2     4     2
# 4            2         0     1     2           1         3     3     3
# ..         ...       ...   ...   ...         ...       ...   ...   ...
# 644          3         1     1     2           1         4     2     3
# 645          2         0     1     1           1         3     3     1
# 646          2         0     1     1           2         1     1     1
# 647          1         0     3     4           2         4     3     1
# 648          1         0     3     4           3         4     3     2
#
#              G
# 0     7.333333
# 1    10.333333
# 2    12.333333
# 3    14.000000
# 4    12.333333
# ..         ...
# ...

# %%
x=np.array(df.drop(['G'],1))
y=np.array(df['G'])   

scaler_svm = StandardScaler()
x = scaler_svm.fit_transform(x)
x
# Out:
# array([[ 0.08365295, -0.37430512, -0.54355533, ..., -0.17164654,
#          1.31021563,  1.54071544],
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -0.17164654,
#         -1.33603938, -1.18883229],
#        [ 0.08365295, -0.37430512,  0.53855329, ..., -0.17164654,
#         -1.33603938, -1.18883229],
#        ...,
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -2.07589613,
#         -1.33603938, -1.18883229],
#        [-1.12280848, -0.37430512,  1.62066191, ...,  0.78047826,
#          0.42813063, -1.18883229],
#        [-1.12280848, -0.37430512,  1.62066191, ...,  0.78047826,
#          0.42813063, -0.27898305]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.33)

# %%
from sklearn.svm import SVR

svm_poly_reg = SVR(epsilon=2.0, kernel = 'rbf')

svm_poly_reg.fit(x, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=2.0,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
accuracy = svm_poly_reg.score(x_test,y_test)  
print(accuracy)
# Out:
# 0.3113594158851115

# %% [markdown]
# ### Let's see how it will work with categorical variables, which I've chosen in *student_performance.ipynb*

# %%
student_with_cat = STUDENTS.copy()

#Attributes to test
student_with_cat = student_with_cat[['sex','school','address','Mjob','Fjob','reason','schoolsup','guardian',
                                     'higher','internet', 'studytime', 'failures', 'Dalc', 'Walc', 
                                     'traveltime', 'freetime', 'Medu', 'Fedu','G1', 'G2', 'G3']]  

student_with_cat
# Out:
#     sex school address      Mjob      Fjob  reason schoolsup guardian higher  \
# 0     F     GP       U   at_home   teacher  course       yes   mother    yes
# 1     F     GP       U   at_home     other  course        no   father    yes
# 2     F     GP       U   at_home     other   other       yes   mother    yes
# 3     F     GP       U    health  services    home        no   mother    yes
# 4     F     GP       U     other     other    home        no   father    yes
# ..   ..    ...     ...       ...       ...     ...       ...      ...    ...
# 644   F     MS       R  services     other  course        no   mother    yes
# 645   F     MS       U   teacher  services  course        no   mother    yes
# 646   F     MS       U     other     other  course        no   mother    yes
# 647   M     MS       U  services  services  course        no   mother    yes
# 648   M     MS       R  services     other  course        no   mother    yes
#
# ...

# %%
features_cat = ['sex','school','address','Mjob','Fjob','reason','schoolsup','guardian','higher','internet']

student_with_cat = pd.get_dummies(student_with_cat, columns = features_cat)
student_with_cat
# Out:
#      studytime  failures  Dalc  Walc  traveltime  freetime  Medu  Fedu  G1  \
# 0            2         0     1     1           2         3     4     4   0
# 1            2         0     1     1           1         3     1     1   9
# 2            2         0     2     3           1         3     1     1  12
# 3            3         0     1     1           1         2     4     2  14
# 4            2         0     1     2           1         3     3     3  11
# ..         ...       ...   ...   ...         ...       ...   ...   ...  ..
# 644          3         1     1     2           1         4     2     3  10
# 645          2         0     1     1           1         3     3     1  15
# 646          2         0     1     1           2         1     1     1  11
# 647          1         0     3     4           2         4     3     1  10
# 648          1         0     3     4           3         4     3     2  10
#
# ...

# %%
#x = np.array(student.drop(['G3'],1))
#y = np.array(student['G3'])  

x = student.drop(['G3'],1)
y = student['G3']

scaler_student_cat = StandardScaler()

x = scaler_student_cat.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.33) 

sgd_reg_st = SGDRegressor(penalty="l2") # specifying Ridge Regression

sgd_reg_st.fit(x_train, y_train)

accuracy=sgd_reg_st.score(x_test,y_test)  
print(accuracy)
# Out:
# 0.7928169073018041

# %% [markdown]
# ### The prediction with categorical variable is worse, than without them - just using plain numerical features
#
# #### Let's see how this will work with SVM

# %%
x
# Out:
# array([[ 0.08365295, -0.37430512, -0.54355533, ...,  1.54071544,
#         -4.15547029, -0.19581961],
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -1.18883229,
#         -0.87456978, -0.19581961],
#        [ 0.08365295, -0.37430512,  0.53855329, ..., -1.18883229,
#          0.21906372,  0.49113675],
#        ...,
#        [ 0.08365295, -0.37430512, -0.54355533, ..., -1.18883229,
#         -0.14548078,  0.14765857],
#        [-1.12280848, -0.37430512,  1.62066191, ..., -1.18883229,
#         -0.51002528, -0.53929779],
#        [-1.12280848, -0.37430512,  1.62066191, ..., -0.27898305,
#         -0.51002528, -0.19581961]])

# %%
svm_poly_reg_cat = SVR(epsilon=2.0, kernel = 'rbf')

svm_poly_reg_cat.fit(x, y)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=2.0,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
accuracy = svm_poly_reg_cat.score(x_test,y_test)  
print(accuracy)
# Out:
# 0.7432667133156883
